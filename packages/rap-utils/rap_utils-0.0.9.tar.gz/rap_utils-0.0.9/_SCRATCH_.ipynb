# %%
# !pip install petl
# Out:
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
from  src.rap_utils.petl.adapters.one_drive import OneDrive

od = OneDrive(
    '5761859f-ee63-474e-8746-4ddcc0d3e9e5',
    '3085c6db-cda1-4917-a274-473a6fdac1c9',
    'MTM8Q~l90G16MEmLGBhv2e2lKMcR8Wk15HJsIckD'
)

# %%
od.list_groups()
# Out:
# +----------------------------------------+------------------------+------------------------------------------------------------------------------------+
# | id                                     | displayName            | description                                                                        |
# +========================================+========================+====================================================================================+
# | '0051ca15-0074-4e42-8ab7-23a6ffd621f3' | 'Relaxed Security'     | 'Users who are more security aware, and are not required to use MS Authentication' |
# +----------------------------------------+------------------------+------------------------------------------------------------------------------------+
# | '1eb438e8-8990-4764-a463-ad9674109539' | 'Opportunities'        | 'Opportunities'                                                                    |
# ...

# %%
from msgraph.graph_service_client import GraphServiceClient 
from azure.identity import DeviceCodeCredential


scopes = ['User.Read']

# Multi-tenant apps can use "common",
# single-tenant apps must use the tenant ID from the Azure portal
tenant_id = 'common'

client_id = '3085c6db-cda1-4917-a274-473a6fdac1c9'


credential = DeviceCodeCredential(
    tenant_id=tenant_id,
    client_id=client_id)

graph_client = GraphServiceClient(credential, scopes)

# %%
graph_client

# %%
config = {
    # Tenant ID
    "authority": "https://login.microsoftonline.com/5761859f-ee63-474e-8746-4ddcc0d3e9e5",
    "client_id": '3085c6db-cda1-4917-a274-473a6fdac1c9',
    "scope": ["https://graph.microsoft.com/.default"],
    "secret": 'MTM8Q~l90G16MEmLGBhv2e2lKMcR8Wk15HJsIckD',
    "endpoint": "https://graph.microsoft.com/v1.0/users"
}

# %%
import msal
import json
import sys
import logging

# %%
app = msal.ConfidentialClientApplication(
    config["client_id"],
    authority=config["authority"],
    client_credential=config["secret"],
    # token_cache=...  # Default cache is in memory only.
                       # You can learn how to use SerializableTokenCache from
                       # https://msal-python.rtfd.io/en/latest/#msal.SerializableTokenCache
    )

# %%
# app.acquire_token_silent(scopes='files.read.all')

app.get_accounts(username='giles.dring@open-innovations.org')
# Out:
# []

# %%
app.get_accounts()
# Out:
# []

# %% [markdown]
# https://learn.microsoft.com/en-us/entra/msal/python/

# %%
# RAP Utils Sample app in Dringtech

config = {
    "tenant_id": "330385b6-938c-4922-9493-f0bb536bfdbf",
    "client_id": "78b2ecd1-dea9-4dd8-acde-5ba24b6edfb9",
    "secret": "_4_8Q~lua-ieTfaqGIru47DuMqHl3y4k1sV~ibss",
}

# %%
import msal

app = msal.ConfidentialClientApplication(
    config["client_id"],
    authority=f"https://login.microsoftonline.com/{ config["tenant_id"] }",
    client_credential=config["secret"],
    # token_cache=...  # Default cache is in memory only.
                       # You can learn how to use SerializableTokenCache from
                       # https://msal-python.rtfd.io/en/latest/#msal.SerializableTokenCache
    )

# %%
app.get_accounts('giles@dringtech.com')
# Out:
# []

# %%
app.acquire_token_by_username_password(
    username="giles@dringtech.com",
    password="W22ngrZrvLxc8Ab4t4iN",
    scopes=["files.read.all"]
)
# Out:
# {'error': 'invalid_grant',
#  'error_description': "AADSTS50076: Due to a configuration change made by your administrator, or because you moved to a new location, you must use multi-factor authentication to access '00000003-0000-0000-c000-000000000000'. Trace ID: 18586869-9843-47e9-a267-87f3e6655400 Correlation ID: 35e81453-3f05-46da-a04b-f8433bfe5f05 Timestamp: 2025-07-14 14:29:38Z",
#  'error_codes': [50076],
#  'timestamp': '2025-07-14 14:29:38Z',
#  'trace_id': '18586869-9843-47e9-a267-87f3e6655400',
#  'correlation_id': '35e81453-3f05-46da-a04b-f8433bfe5f05',
#  'error_uri': 'https://login.microsoftonline.com/error?code=50076',
#  'suberror': 'basic_action'}

# %%
result = app.acquire_token_by_auth_code_flow(
    app.initiate_auth_code_flow(scopes=["files.read.all"]),
    scopes=["files.read.all"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 result = app.acquire_token_by_auth_code_flow(
#       2     app.initiate_auth_code_flow(scopes=["files.read.all"]),
#       3     scopes=["files.read.all"])
#
# TypeError: ClientApplication.acquire_token_by_auth_code_flow() missing 1 required positional argument: 'auth_response'
