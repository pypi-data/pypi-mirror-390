# %%
from pyEDM import sampleData
df = sampleData['Lorenz5D']

# %%
import dimx as dx

# %%
m = dx.MDE()

# %%
try:
    m.Run()
except RuntimeError :
    print( 'Run failed' )

# %%
m = dx.MDE( df, target = 'V1', D = 4, removeColumns = ['Time','V1'],
            embedDimRhoMin = 0.1, crossMapRhoMin = 0.1, verbose = True )

# %%
m.Run()

# %%
m.MDEOut
