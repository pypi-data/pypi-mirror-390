# %% [markdown]
# ## Name: Aman Prabhune
#
#
# ## Implement the Image classification CNN modelfor classifying hand-written MNISTdataset by dividing the model into following 4 stages:
#     a. Loadingand preprocessingtheimagedata
#     b. Definingthemodel'sarchitecture
#     c. Trainingthe model
#     d. Estimatingthemodel'sperformance

# %%
from tensorflow.keras.datasets import mnist

# %%
(X_train,y_train),(X_test,y_test) = mnist.load_data()

# %%
X_train = X_train/255.0
X_test = X_test/255.0

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPool2D,Flatten,Dense

# %%
model = Sequential([
    Conv2D(128,(3,3),activation = 'relu',input_shape=(28,28,1)),
    MaxPool2D((2,2)),
    Conv2D(64,(3,3),activation = 'relu'),
    MaxPool2D((2,2)),
    Conv2D(32,(3,3),activation = 'relu'),
    MaxPool2D((2,2)),
    Flatten(),
    Dense(32,activation = 'relu'),
    Dense(10,activation = 'softmax')    
])

model.summary()
# Out:
# 2023-11-09 22:43:05.517555: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1
# 2023-11-09 22:43:05.517610: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 8.00 GB
# 2023-11-09 22:43:05.517632: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 2.67 GB
# 2023-11-09 22:43:05.517847: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-11-09 22:43:05.518246: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 128)       1280
#
#  max_pooling2d (MaxPooling2  (None, 13, 13, 128)       0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        73792
#
#  max_pooling2d_1 (MaxPoolin  (None, 5, 5, 64)          0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 3, 3, 32)          18464
#
#  max_pooling2d_2 (MaxPoolin  (None, 1, 1, 32)          0
#  g2D)
#
#  flatten (Flatten)           (None, 32)                0
#
#  dense (Dense)               (None, 32)                1056
#
#  dense_1 (Dense)             (None, 10)                330
#
# =================================================================
# Total params: 94922 (370.79 KB)
# Trainable params: 94922 (370.79 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from tensorflow.keras.losses import SparseCategoricalCrossentropy
model.compile(optimizer='adam',loss=SparseCategoricalCrossentropy(),metrics=['accuracy'])

# %%
epochs = 2
H  = model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=epochs)
# Out:
# Epoch 1/2
# 2023-11-09 22:43:15.509101: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.2706 - accuracy: 0.9147 - val_loss: 0.1207 - val_accuracy: 0.9640
# Epoch 2/2
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0998 - accuracy: 0.9700 - val_loss: 0.0832 - val_accuracy: 0.9759

# %%
from sklearn.metrics import classification_report
prediction = model.predict(X_test)
print(classification_report(y_test,prediction.argmax(axis=1)))
# Out:
# 313/313 [==============================] - 2s 5ms/step
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98       980
#            1       0.99      0.99      0.99      1135
#            2       0.97      0.98      0.97      1032
#            3       0.99      0.97      0.98      1010
#            4       0.98      0.99      0.98       982
#            5       0.93      0.99      0.96       892
#            6       0.99      0.99      0.99       958
#            7       0.96      0.98      0.97      1028
#            8       0.99      0.94      0.97       974
#            9       0.99      0.94      0.97      1009
#
#     accuracy                           0.98     10000
#    macro avg       0.98      0.98      0.98     10000
# weighted avg       0.98      0.98      0.98     10000

# %%
import matplotlib.pyplot as plt
plt.plot(range(0,epochs),H.history['accuracy'],label = 'train_accuracy')
plt.plot(range(0,epochs),H.history['val_accuracy'],label = 'test_accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()

# %%
import matplotlib.pyplot as plt
plt.plot(range(0,epochs),H.history['loss'],label = 'train_loss')
plt.plot(range(0,epochs),H.history['val_loss'],label = 'test_loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid();
